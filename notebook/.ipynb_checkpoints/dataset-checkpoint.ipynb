# %% [markdown]
# # Generate The Dataset

# %%
import numpy as np  # for array
import pandas as pd  # for csv files and dataframe
import matplotlib.pyplot as plt  # for plotting
import seaborn as sns  # plotting

import warnings
warnings.filterwarnings("ignore")

# Set seaborn
sns.set()

# %% [markdown]
# import tensorflow as tf
# print(tf.config.list_physical_devices('GPU'))

# %% [markdown]
# ## 1. IoTBotnet Dataset

# %%
# Reading datasets
# 04_Semester_4/revisi/dataset/UNSW_2018_IoT_Botnet_Full5pc_1.csv
dfs = []
for i in range(1,5):
    path = '~/04_Semester_4/revisi/dataset/UNSW_2018_IoT_Botnet_Full5pc_{}.csv'  # There are 4 input csv files
    dfs.append(pd.read_csv(path.format(i), low_memory=False))
all_data = pd.concat(dfs).reset_index(drop=True)  # Concat all to a single df

# %%
all_data.head()
# Out:
#    pkSeqID         stime flgs  flgs_number proto  proto_number  \
# 0        1  1.528089e+09    e            1   tcp             1
# 1        2  1.528089e+09    e            1   arp             2
# 2        3  1.528089e+09    e            1   tcp             1
# 3        4  1.528089e+09    e            1   tcp             1
# 4        5  1.528089e+09    e            1   tcp             1
#
#              saddr  sport            daddr dport  ...  AR_P_Proto_P_DstIP  \
# 0  192.168.100.147  49960    192.168.100.7    80  ...             1.12704
# 1    192.168.100.7     -1  192.168.100.147    -1  ...         15267.20000
# 2  192.168.100.147  49962    192.168.100.7    80  ...             1.12704
# 3  192.168.100.147  49964    192.168.100.7    80  ...             1.12704
# 4  192.168.100.147  49966    192.168.100.7    80  ...             1.12704
#
#    N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 0                 96                75            1.133720
# 1                  1                 2            0.005142
# 2                 96                75            1.135100
# 3                 96                75            1.135140
# 4                 96                75            1.135260
#
#    AR_P_Proto_P_Dport  Pkts_P_State_P_Protocol_P_DestIP  \
# 0            1.129970                               770
# 1            0.005142                                 2
# 2            1.129970                               770
# 3            1.129970                               770
# 4            1.129970                               770
#
#    Pkts_P_State_P_Protocol_P_SrcIP  attack  category  subcategory
# 0                              602       1       DoS         HTTP
# 1                                6       1       DoS         HTTP
# 2                              602       1       DoS         HTTP
# 3                              602       1       DoS         HTTP
# 4                              602       1       DoS         HTTP
#
# [5 rows x 46 columns]

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3668522 entries, 0 to 3668521
# Data columns (total 46 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   pkSeqID                           int64
#  1   stime                             float64
#  2   flgs                              object
#  3   flgs_number                       int64
#  4   proto                             object
#  5   proto_number                      int64
#  6   saddr                             object
#  7   sport                             object
#  8   daddr                             object
#  9   dport                             object
#  10  pkts                              int64
#  11  bytes                             int64
#  12  state                             object
#  13  state_number                      int64
#  14  ltime                             float64
#  15  seq                               int64
#  16  dur                               float64
#  17  mean                              float64
#  18  stddev                            float64
#  19  sum                               float64
#  20  min                               float64
#  21  max                               float64
#  22  spkts                             int64
#  23  dpkts                             int64
#  24  sbytes                            int64
#  25  dbytes                            int64
#  26  rate                              float64
#  27  srate                             float64
#  28  drate                             float64
#  29  TnBPSrcIP                         int64
#  30  TnBPDstIP                         int64
#  31  TnP_PSrcIP                        int64
#  32  TnP_PDstIP                        int64
#  33  TnP_PerProto                      int64
#  34  TnP_Per_Dport                     int64
#  35  AR_P_Proto_P_SrcIP                float64
#  36  AR_P_Proto_P_DstIP                float64
#  37  N_IN_Conn_P_DstIP                 int64
#  38  N_IN_Conn_P_SrcIP                 int64
#  39  AR_P_Proto_P_Sport                float64
#  40  AR_P_Proto_P_Dport                float64
#  41  Pkts_P_State_P_Protocol_P_DestIP  int64
#  42  Pkts_P_State_P_Protocol_P_SrcIP   int64
#  43  attack                            int64
#  44  category                          object
#  45  subcategory                       object
# dtypes: float64(15), int64(22), object(9)
# memory usage: 1.3+ GB

# %%
all_data.isnull().sum()
# Out:
# pkSeqID                             0
# stime                               0
# flgs                                0
# flgs_number                         0
# proto                               0
# proto_number                        0
# saddr                               0
# sport                               0
# daddr                               0
# dport                               0
# pkts                                0
# bytes                               0
# state                               0
# state_number                        0
# ltime                               0
# seq                                 0
# dur                                 0
# mean                                0
# stddev                              0
# sum                                 0
# min                                 0
# max                                 0
# spkts                               0
# dpkts                               0
# sbytes                              0
# dbytes                              0
# rate                                0
# srate                               0
# drate                               0
# TnBPSrcIP                           0
# TnBPDstIP                           0
# TnP_PSrcIP                          0
# TnP_PDstIP                          0
# TnP_PerProto                        0
# TnP_Per_Dport                       0
# AR_P_Proto_P_SrcIP                  0
# AR_P_Proto_P_DstIP                  0
# N_IN_Conn_P_DstIP                   0
# N_IN_Conn_P_SrcIP                   0
# AR_P_Proto_P_Sport                  0
# AR_P_Proto_P_Dport                  0
# Pkts_P_State_P_Protocol_P_DestIP    0
# Pkts_P_State_P_Protocol_P_SrcIP     0
# attack                              0
# category                            0
# subcategory                         0
# dtype: int64

# %%
all_data.value_counts('attack')
# Out:
# attack
# 1    3668045
# 0        477
# Name: count, dtype: int64

# %%
# Select interested data features
data=all_data[['proto','saddr','sport','daddr','dport','spkts','dpkts','sbytes','dbytes','state','stime','ltime','dur','attack','category']]

# %%
# Plotting target label
plt.figure(figsize=(15,4))
sns.set_theme(style="darkgrid")
sns.countplot(x=data['attack'],palette='CMRmap')
plt.title('The distribution of the target label in IoT Bot 5% dataset', weight='bold', fontsize='18')
plt.show()

# %%
# Plotting target label
plt.figure(figsize=(15,4))
sns.set_theme(style="darkgrid")
sns.countplot(x=data['attack'],palette='CMRmap')
plt.title('Distribusi target label di dataset IoT Bot 5%', weight='bold', fontsize='18')
plt.show()

# %%
data.value_counts('category')
# Out:
# category
# DDoS              1926624
# DoS               1650260
# Reconnaissance      91082
# Normal                477
# Theft                  79
# Name: count, dtype: int64

# %%
# Plotting target label
plt.figure(figsize=(15,4))
sns.set_theme(style="darkgrid")
sns.countplot(x=data['category'],palette='CMRmap')
plt.title('Distribusi target Kategori di IoT Bot 5% dataset', weight='bold', fontsize='18')
plt.show()

# %%
data = pd.read_csv('~/04_Semester_4/revisi/csv_files/IoT_Botnet_Full5pc.csv', low_memory=False)

# %%
# Shuffle dataframe
data=data.sample(frac=1, random_state=99)

n=data.shape[0]

data_train = data.iloc[:round(0.8*n),:] # 80% of dataset
data_test = data.iloc[round(0.8*n):,:] # 20% of datas

# %%
# save to csv files
data_train.to_csv('~/04_Semester_4/revisi/csv_files/IoT_Botnet_Full5pc_train.csv', index=False)
data_test.to_csv('~/04_Semester_4/revisi/csv_files/IoT_Botnet_Full5pc_test.csv', index=False)

# %% [markdown]
# ## 2. UNSW-NB15 Dataset

# %%
# Reading datasets
dfs = []
for i in range(1,5):
    path = '~/04_Semester_4/revisi/dataset/UNSW-NB15_{}.csv'  # There are 4 input csv files
    dfs.append(pd.read_csv(path.format(i), header = None))
all_data = pd.concat(dfs).reset_index(drop=True)  # Concat all to a single df

# %%
# This csv file contains names of all the features
df_col = pd.read_csv('~/04_Semester_4/revisi/dataset/NUSW-NB15_features.csv', encoding='ISO-8859-1')

# Making column names lower case, removing spaces
df_col['Name'] = df_col['Name'].apply(lambda x: x.strip().replace(' ', '').lower())

# Renaming our dataframe with proper column names
all_data.columns = df_col['Name']
del df_col

# %%
all_data['attack_cat'] = all_data.attack_cat.fillna(value='normal').apply(lambda x: x.strip().lower())

# %%
all_data['attack_cat'] = all_data['attack_cat'].replace('backdoors','backdoor', regex=True).apply(lambda x: x.strip().lower())

# %%
# Select features
all_data=all_data[['proto','srcip','sport','dstip','dsport','spkts','dpkts','sbytes','dbytes','state','stime','ltime','dur', 'label', 'attack_cat']]

# %%
all_data.head()
# Out:
# Name proto       srcip  sport          dstip dsport  spkts  dpkts  sbytes  \
# 0      udp  59.166.0.0   1390  149.171.126.6     53      2      2     132
# 1      udp  59.166.0.0  33661  149.171.126.9   1024      4      4     528
# 2      udp  59.166.0.6   1464  149.171.126.7     53      2      2     146
# 3      udp  59.166.0.5   3593  149.171.126.5     53      2      2     132
# 4      udp  59.166.0.3  49664  149.171.126.0     53      2      2     146
#
# Name  dbytes state       stime       ltime       dur  label attack_cat
# 0        164   CON  1421927414  1421927414  0.001055      0     normal
# 1        304   CON  1421927414  1421927414  0.036133      0     normal
# 2        178   CON  1421927414  1421927414  0.001119      0     normal
# 3        164   CON  1421927414  1421927414  0.001209      0     normal
# 4        178   CON  1421927414  1421927414  0.001169      0     normal

# %%
all_data.to_csv('~/04_Semester_4/revisi/csv_files/UNSW-NB15.csv', index=False)

# %% [markdown]
# ### A. UNSW-NB15 Base 5

# %%
data = pd.read_csv('~/04_Semester_4/revisi/csv_files/UNSW-NB15.csv', low_memory=False)

# %%
data.head()
# Out:
#   proto       srcip  sport          dstip dsport  spkts  dpkts  sbytes  \
# 0   udp  59.166.0.0   1390  149.171.126.6     53      2      2     132
# 1   udp  59.166.0.0  33661  149.171.126.9   1024      4      4     528
# 2   udp  59.166.0.6   1464  149.171.126.7     53      2      2     146
# 3   udp  59.166.0.5   3593  149.171.126.5     53      2      2     132
# 4   udp  59.166.0.3  49664  149.171.126.0     53      2      2     146
#
#    dbytes state       stime       ltime       dur  label attack_cat
# 0     164   CON  1421927414  1421927414  0.001055      0     normal
# 1     304   CON  1421927414  1421927414  0.036133      0     normal
# 2     178   CON  1421927414  1421927414  0.001119      0     normal
# 3     164   CON  1421927414  1421927414  0.001209      0     normal
# 4     178   CON  1421927414  1421927414  0.001169      0     normal

# %%
# Selecting attack type in different dataframes
normal = data.loc[data['attack_cat'] == 'normal', :]
generic = data.loc[data['attack_cat'] == 'generic', :]
exploits = data.loc[data['attack_cat'] == 'exploits', :]
fuzzers = data.loc[data['attack_cat'] == 'fuzzers', :]
dos = data.loc[data['attack_cat'] == 'dos', :]
reconnaissance = data.loc[data['attack_cat'] == 'reconnaissance', :]
analysis = data.loc[data['attack_cat'] == 'analysis', :]
backdoor = data.loc[data['attack_cat'] == 'backdoor', :]
shellcode = data.loc[data['attack_cat'] == 'shellcode', :]
worms = data.loc[data['attack_cat'] == 'worms', :]

# %%
def cut_off(data=data):
    attacks = data.loc[data['label'] == 1, :]
    n_attacks = len(attacks)
    no_attacks_all = data.loc[data['label'] == 0, :]
    no_attacks = no_attacks_all.sample(n=n_attacks, random_state=42)
    data = pd.concat([attacks, no_attacks])
    return data

# %%
data.value_counts('attack_cat')
# Out:
# attack_cat
# normal            2218764
# generic            215481
# exploits            44525
# fuzzers             24246
# dos                 16353
# reconnaissance      13987
# analysis             2677
# backdoor             2329
# shellcode            1511
# worms                 174
# Name: count, dtype: int64

# %%
# Creating the base4 Dataset  detection of zero-day attack, 3 category
#(fuzzers, analysis, backdoor, shellcode, and worms).
base5 = pd.concat([normal, generic, exploits, dos, reconnaissance])

# %%
all_0, all_1 = base5['label'].value_counts()[0]*100 / len(base5.index), base5['label'].value_counts()[1]*100 / len(base5.index)

print("In base5 dataset: there are {} % of normal traffic and {} % of attacks".format(all_0, all_1))
# Out:
# In base5 dataset: there are 88.42832717577149 % of normal traffic and 11.57167282422851 % of attacks

# %%
# Balancing the dataset to obtain 50/50% attacks/normal traffic
base5=cut_off(base5)

# %%
all_0, all_1 = base5['label'].value_counts()[0]*100 / len(base5.index), base5['label'].value_counts()[1]*100 / len(base5.index)

print("In base5 dataset: there are {} % of normal traffic and {} % of attacks".format(all_0, all_1))
# Out:
# In base5 dataset: there are 50.0 % of normal traffic and 50.0 % of attacks

# %%
base5.value_counts('label')
# Out:
# label
# 0    290346
# 1    290346
# Name: count, dtype: int64

# %%
# Plotting target label
plt.figure(figsize=(15,4))
sns.set_theme(style="darkgrid")
sns.countplot(x=base5['label'],palette='CMRmap')
plt.title('Distribusi target label di Base 5 dataset', weight='bold', fontsize='18')
plt.show()

# %%
# Plotting attack category distribution
plt.figure(figsize=(15, 4))
sns.set_theme(style="darkgrid")
sns.countplot(x=base5['attack_cat'], order = base5['attack_cat'].value_counts().index, palette='CMRmap')
plt.title('Distribusi kategori serangan di Base 5 dataset', weight='bold', fontsize='18')
plt.yticks(weight='bold', fontsize=12)
plt.show()

# %%
# Shuffle dataframe
base5=base5.sample(frac=1, random_state=42)

n=base5.shape[0]

base5_train = base5.iloc[:round(0.75*n),:] # 75% of dataset
base5_test = base5.iloc[round(0.75*n):,:] # 25% of datas

# %% [markdown]
# ### B. Base5 Train

# %%
all_0, all_1 = base5_train['label'].value_counts()[0]*100 / len(base5_train.index), base5_train['label'].value_counts()[1]*100 / len(base5_train.index)

print("In Base 5 train dataset: there are {} % of normal traffic and {} % of attacks".format(all_0, all_1))
# Out:
# In Base 5 train dataset: there are 50.02032058302852 % of normal traffic and 49.97967941697148 % of attacks

# %%
# Plotting target label
plt.figure(figsize=(15,4))
sns.set_theme(style="darkgrid")
sns.countplot(x=base5_train['label'],  palette='CMRmap')
plt.title('Distribusi target label di Base 5 train dataset', weight='bold', fontsize='18')
plt.show()

# %%
# Plotting attack category distribution
plt.figure(figsize=(15, 4))
sns.set_theme(style="darkgrid")
sns.countplot(x=base5_train['attack_cat'], order = base5_train['attack_cat'].value_counts().index, palette='CMRmap')
plt.title('Distribusi kategori serangan di Base 5 train dataset', weight='bold', fontsize='18')
plt.yticks(weight='bold', fontsize=12)
plt.show()

# %%
base5_train.value_counts('label')
# Out:
# label
# 0    217848
# 1    217671
# Name: count, dtype: int64

# %% [markdown]
# ### C. Base5test

# %%
base5_test
print("In base5_test dataset: there are {} % of normal traffic and {} % of attacks".format(all_0, all_1))
# Out:
# In base5_test dataset: there are 50.02032058302852 % of normal traffic and 49.97967941697148 % of attacks

# %%
# Plotting target label
plt.figure(figsize=(15,4))
sns.set_theme(style="darkgrid")
sns.countplot(x=base5_test['label'],  palette='CMRmap')
plt.title('Distribusi label target di Base 5 test dataset', weight='bold', fontsize='18')
plt.show()

# %%
# Plotting attack category distribution
plt.figure(figsize=(15, 4))
sns.set_theme(style="darkgrid")
sns.countplot(x=base5_test['attack_cat'], order = base5_test['attack_cat'].value_counts().index, palette='CMRmap')
plt.title('Distribusi kategori serangan di Base 5 test dataset', weight='bold', fontsize='18')
plt.yticks(weight='bold', fontsize=12)
plt.show()

# %%
base5_test['attack_cat'].value_counts()
# Out:
# attack_cat
# normal            72498
# generic           53885
# exploits          11053
# dos                4154
# reconnaissance     3583
# Name: count, dtype: int64

# %% [markdown]
# ### D. first_test

# %%
# Creating the Base 5+ test dataset generic, exploits, DoS, and reconnaissance)
first_test = pd.concat([normal, fuzzers, analysis, backdoor, shellcode, worms])

# %%
# Balancing the dataset to obtain 50/50% attacks/normal traffic
first_test=cut_off(first_test)

# %%
all_0, all_1 = first_test['label'].value_counts()[0]*100 / len(first_test.index), first_test['label'].value_counts()[1]*100 / len(first_test.index)

print("In First test : there are {} % of normal traffic and {} % of attacks".format(all_0, all_1))
# Out:
# In First test : there are 50.0 % of normal traffic and 50.0 % of attacks

# %%
# Plotting target label
plt.figure(figsize=(15,4))
sns.set_theme(style="darkgrid")
sns.countplot(x=first_test['label'],  palette='CMRmap')
plt.title('Distribusi label target di First_test dataset', weight='bold', fontsize='18')
plt.show()

# %%
# Plotting attack category distribution
plt.figure(figsize=(15, 4))
sns.set_theme(style="darkgrid")
sns.countplot(x=first_test['attack_cat'], order = first_test['attack_cat'].value_counts().index, palette='CMRmap')
plt.title('Distribusi serangan di first_test dataset', weight='bold', fontsize='18')
plt.yticks(weight='bold', fontsize=12)
plt.show()

# %%
first_test['attack_cat'].value_counts()
# Out:
# attack_cat
# normal       30937
# fuzzers      24246
# analysis      2677
# backdoor      2329
# shellcode     1511
# worms          174
# Name: count, dtype: int64

# %% [markdown]
# ### E. Base Test

# %%
# Creating the UNSW-NB15-base test
full_test = cut_off(data)

# %%
# Plotting target label
plt.figure(figsize=(15,4))
sns.set_theme(style="darkgrid")
sns.countplot(x=full_test['label'],  palette='CMRmap')
plt.title('Distribusi label target di full_test dataset', weight='bold', fontsize='18')
plt.show()

# %%
# Plotting attack category distribution
plt.figure(figsize=(15, 4))
sns.set_theme(style="darkgrid")
sns.countplot(x=full_test['attack_cat'], order = full_test['attack_cat'].value_counts().index, palette='CMRmap')
plt.title('Distribusi serangan di full_test dataset', weight='bold', fontsize='18')
plt.yticks(weight='bold', fontsize=12)
plt.show()

# %%
full_test.value_counts('attack_cat')
# Out:
# attack_cat
# normal            321283
# generic           215481
# exploits           44525
# fuzzers            24246
# dos                16353
# reconnaissance     13987
# analysis            2677
# backdoor            2329
# shellcode           1511
# worms                174
# Name: count, dtype: int64

# %%
base5.to_csv('~/04_Semester_4/revisi/csv_files/UNSW_NB15_base5.csv', index=False)
base5_train.to_csv('~/04_Semester_4/revisi/csv_files/UNSW_NB15_base5_train.csv', index=False)
base5_test.to_csv('~/04_Semester_4/revisi/csv_files/UNSW_NB15_base5_test.csv', index=False)
first_test.to_csv('~/04_Semester_4/revisi/csv_files/UNSW_NB15_first_test.csv', index=False)
full_test.to_csv('~/04_Semester_4/revisi/csv_files/UNSW_NB15_full_test.csv', index=False)
